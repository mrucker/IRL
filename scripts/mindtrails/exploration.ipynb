# %%
import pandas as pd

df = pd.read_csv('../../data/mindtrails/action_log.csv')

df['income'] = df['income'].str.replace("$","",regex=False).str.replace(",","",regex=False).str.replace(" through ", "-", regex=False)

# %%
df
# Out:
#         participant_id      action_name               date.x  latency  \
# 0                 2071        wrongWill  2020-10-09 20:32:00     2542
# 1                 2071        wrongWill  2020-10-09 20:32:02     2575
# 2                 2071   compActWilling  2020-10-09 20:32:15     5749
# 3                 2071      elevator_NS  2020-10-09 20:18:08    28523
# 4                 2071         pleasure  2020-10-09 20:31:10     5522
# ...                ...              ...                  ...      ...
# 240232            3715         howOften  2020-11-27 13:59:51    11967
# 240233            3715   numberOfDrinks  2020-11-27 13:59:58     6410
# 240234            3715        sixOrMore  2020-11-27 14:00:04     5917
# 240235            3715     satisfaction  2020-11-27 14:00:27    21084
# 240236            3715  accomplishTasks  2020-11-27 14:00:43    15692
#
#         session_name study_name   task_name               date.y  session  \
# ...

# %%
row = next(df.sort_values(["date.x"]).iterrows())

# %%
row
# Out:
# (7162,
#  participant_id                       2368
#  action_name                   PosFeelings
#  date.x                2020-09-08 11:29:06
#  latency                              5864
#  session_name                 fifthSession
#  study_name                           GIDI
#  task_name                          Affect
#  date.y                2020-08-02 14:29:58
#  session                           preTest
#  time_on_page                       84.642
#  birth_year                         1951.0
#  country                     United States
#  education                 Master's Degree
#  employment_stat         Working part-time
#  ethnicity          Not Hispanic or Latino
#  gender                               Male
#  income                                555
#  marital_stat                      Married
#  Name: 7162, dtype: object)
